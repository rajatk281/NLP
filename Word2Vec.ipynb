# %% [markdown]
# # Word2Vec

# %%
import nltk
from gensim.models import Word2Vec
from nltk.corpus import stopwords
import re

# %%
paragraph="""This win is as much for the fans as it is for the team. Its been 18 long years. Ive given this team my youth, prime and experience. Ive tried to win it every season, gave it everything I have. To finally have it is an unbelievable feeling. Never thought this day would come, I was overcome with emotion after the last ball was bowled. Gave each and every ounce of my energy and its an amazing feeling. What ABD has done for the franchise is tremendous, told him this win is as much yours as it is ours. I want you to celebrate with us. Hes been the POTM most times in the franchise despite being retired for four years. Tells you the impact hes had on the league, team and me. He deserves to be on the podium, lifting the cup.Well, its right up there, if I have to be honest. As I said, Ive given everything that I had for the last 18 years. Ive stayed loyal to this team, no matter what. Ive had moments where I thought otherwise, but I stuck to this team. I stood behind them, they stood behind me. And I always dreamt of winning it with them. And this is far more special than winning it with anyone else because my heart is with Bangalore, my soul is with Bangalore. And as I said, this is the team Im going to play for till the last day that I play the IPL. So this one is absolutely right up there because you know, as a sportsman, when you grind for something, and this is a very high intensity, high quality tournament, which is of great value in world cricket today. And Im someone that wants to win the big tournaments, the big moments, and this one was missing. And tonight, Im going to sleep like a baby."""

# %% [markdown]
# ### Pre Processing of Data

# %%
text = re.sub(r'\[[0-9]*\]', ' ', paragraph)
text = re.sub(r'\s+', ' ', text)
text = text.lower()
text = re.sub(r'\d', ' ', text)
text = re.sub(r'\s+', ' ', text)
text
# Out:
# 'this win is as much for the fans as it is for the team. its been long years. ive given this team my youth, prime and experience. ive tried to win it every season, gave it everything i have. to finally have it is an unbelievable feeling. never thought this day would come, i was overcome with emotion after the last ball was bowled. gave each and every ounce of my energy and its an amazing feeling. what abd has done for the franchise is tremendous, told him this win is as much yours as it is ours. i want you to celebrate with us. hes been the potm most times in the franchise despite being retired for four years. tells you the impact hes had on the league, team and me. he deserves to be on the podium, lifting the cup.well, its right up there, if i have to be honest. as i said, ive given everything that i had for the last years. ive stayed loyal to this team, no matter what. ive had moments where i thought otherwise, but i stuck to this team. i stood behind them, they stood behind me. and i always dreamt of winning it with them. and this is far more special than winning it with anyone else because my heart is with bangalore, my soul is with bangalore. and as i said, this is the team im going to play for till the last day that i play the ipl. so this one is absolutely right up there because you know, as a sportsman, when you grind for something, and this is a very high intensity, high quality tournament, which is of great value in world cricket today. and im someone that wants to win the big tournaments, the big moments, and this one was missing. and tonight, im going to sleep like a baby.'

# %% [markdown]
# ### Preparing the Dataset

# %%
sentences=nltk.sent_tokenize(text)
sentences = [nltk.word_tokenize(sentence) for sentence in sentences]
for i in range(len(sentences)):
    sentences[i] = [word for word in sentences[i] if word not in stopwords.words('english')]

# %% [markdown]
# ### Training and Word2Vec model

# %%
model = Word2Vec(sentences, min_count=1)

# %%
words = model.wv.index_to_key
words
# Out:
# [',',
#  '.',
#  'team',
#  'ive',
#  'win',
#  'im',
#  'last',
#  'years',
#  'big',
#  'high',
#  'one',
#  'play',
#  'going',
#  'bangalore',
#  'winning',
#  'behind',
#  'stood',
#  'moments',
#  'said',
#  'right',
#  'hes',
#  'franchise',
#  'day',
#  'thought',
#  'feeling',
#  'everything',
#  'gave',
#  'every',
#  'given',
#  'much',
#  'baby',
#  'like',
#  'sleep',
#  'tonight',
#  'missing',
#  'tournaments',
#  'wants',
#  'someone',
#  'today',
#  'cricket',
#  'world',
#  'value',
#  'great',
#  'tournament',
#  'quality',
#  'intensity',
#  'something',
#  'grind',
#  'sportsman',
#  'know',
#  'absolutely',
#  'ipl',
#  'till',
#  'soul',
#  'heart',
#  'else',
#  'anyone',
#  'special',
#  'far',
#  'dreamt',
#  'always',
#  'stuck',
#  'otherwise',
#  'matter',
#  'loyal',
#  'stayed',
#  'honest',
#  'cup.well',
#  'lifting',
#  'podium',
#  'deserves',
#  'league',
#  'impact',
#  'tells',
#  'four',
#  'retired',
#  'despite',
#  'times',
#  'potm',
#  'us',
#  'celebrate',
#  'want',
#  'told',
#  'tremendous',
#  'done',
#  'abd',
#  'amazing',
#  'energy',
#  'ounce',
#  'bowled',
#  'ball',
#  'emotion',
#  'overcome',
#  'come',
#  'would',
#  'never',
#  'unbelievable',
#  'finally',
#  'season',
#  'tried',
#  'experience',
#  'prime',
#  'youth',
#  'long',
#  'fans']

# %%
vector=model.wv['feeling']
vector
# Out:
# array([-4.9788044e-03, -1.2690459e-03,  3.2833256e-03, -6.4115953e-03,
#        -9.6969595e-03, -9.2825098e-03,  9.0358518e-03,  5.3962697e-03,
#        -4.7996510e-03, -8.3256401e-03,  1.2893513e-03,  2.8679755e-03,
#        -1.2476669e-03,  1.2803145e-03, -4.3167300e-03,  4.7807181e-03,
#         1.4811931e-03,  8.8809058e-03, -9.9889338e-03, -5.2937474e-03,
#        -9.0954173e-03, -3.5512520e-04, -7.8367414e-03,  5.0205835e-03,
#        -6.3972259e-03, -5.9601627e-03,  5.0604530e-03, -8.1601432e-03,
#         1.4390275e-03, -7.2386921e-03,  9.8667983e-03,  8.6365128e-03,
#         1.7921330e-03,  5.7757352e-03,  4.5939544e-03, -5.9851292e-03,
#         9.7653652e-03, -9.6873678e-03,  8.0610616e-03,  2.7326762e-03,
#        -3.0536817e-03, -3.5707881e-03,  9.0604750e-03, -5.4594120e-03,
#         8.1908507e-03, -6.0026138e-03,  8.3795581e-03, -5.4057315e-04,
#         7.9546031e-03, -3.1476475e-03,  5.9740478e-03,  8.7972851e-03,
#         2.5526809e-03,  1.3189239e-03,  5.0444920e-03,  8.0086673e-03,
#         8.5732667e-03,  8.4974347e-03,  7.0334035e-03,  8.0057634e-03,
#         8.5995970e-03, -3.5407655e-05, -1.0029370e-03,  1.6605330e-03,
#         2.4976080e-06,  6.9749152e-04, -8.5966717e-03, -9.5869210e-03,
#        -2.3269469e-03,  8.9487312e-03, -3.6514292e-03, -6.9724149e-03,
#         4.8897490e-03,  1.0663100e-03,  1.8581270e-03,  3.6499312e-03,
#         3.5237018e-03,  5.7244874e-03,  1.2270466e-03,  8.3330140e-04,
#         9.0462761e-03,  2.7878687e-03, -4.7148587e-03,  6.5634842e-03,
#         5.1976242e-03,  2.8599452e-03, -3.1173490e-03,  3.3323483e-03,
#         6.3721272e-03,  7.0962906e-03,  9.7029970e-04, -8.5251937e-03,
#         2.5565180e-04,  3.6241731e-04,  3.9691101e-03, -9.4607063e-03,
#         9.7005442e-03, -6.9893925e-03,  5.7561672e-03, -9.4395122e-03],
#       dtype=float32)

# %%
similar=model.wv.most_similar('feeling')
similar
# Out:
# [('never', 0.24182604253292084),
#  ('value', 0.19328360259532928),
#  ('impact', 0.18375933170318604),
#  ('times', 0.179218590259552),
#  ('ball', 0.1761743128299713),
#  ('potm', 0.1687343269586563),
#  ('retired', 0.16441631317138672),
#  ('great', 0.15849615633487701),
#  ('absolutely', 0.1581091731786728),
#  ('unbelievable', 0.1440335214138031)]
